# %%
# YOLOv8 Nesne Tanıma

# %% [markdown]
# ## Ortam Hazırlığı

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Computer Vision/YOLOv8/1_object_detection
# Out:
# /content/drive/MyDrive/Colab Notebooks/Computer Vision/YOLOv8/1_object_detection

# %%
# ultralytics indir.
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# ## Test/Prediction

# %%
# !yolo detect predict model=yolov8n.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 67.3MB/s]
# Ultralytics YOLOv8.0.230 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 12.8MB/s]
# image 1/1 /content/drive/MyDrive/Colab Notebooks/Computer Vision/YOLOv8/1_object_detection/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 319.3ms
# Speed: 21.5ms preprocess, 319.3ms inference, 37.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Training

# %%
# !unzip data/brain_tumor_dataset.zip -d ./data
# Out:
# Archive:  data/brain_tumor_dataset.zip
#    creating: ./data/brain_tumor_dataset/images/
#    creating: ./data/brain_tumor_dataset/images/test/
#   inflating: ./data/brain_tumor_dataset/images/test/112.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/117.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/136.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/140.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/142.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/146.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/149.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/154.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/161.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/17.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/181.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/191.jpg
#   inflating: ./data/brain_tumor_dataset/images/test/208.jpg
# ...

# %%
# !yolo detect train data=data/config.yaml model=yolov8n.pt epochs=25 imgsz=640 workers=8 batch=8 device=0 name=yolov8_brain_tumor_detection
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Tümör Tespiti / Prediction

# %%
# !yolo detect source=inference model='/content/drive/MyDrive/Colab Notebooks/Computer Vision/YOLOv8/1_object_detection/runs/detect/yolov8_brain_tumor_detection/weights/best.pt' save=True
# Out:
# WARNING ⚠️ 'mode' is missing. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark'). Using default 'mode=train'.
# WARNING ⚠️ 'data' is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
